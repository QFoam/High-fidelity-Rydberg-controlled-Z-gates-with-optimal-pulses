# %%
# %matplotlib inline
import matplotlib.pyplot as plt  # Import library for direct plotting functions
import numpy as np  # Import Numerical Python
from IPython.display import display, HTML

# %%
from arc import *

# %%
# Load parameters for Caesium
# atom = Caesium()
atom = Rubidium()

nmin = 40  # Minimum n
nmax = 45  # Maximum n
lmin = 0  # Minimum l
lmax = 3  # Maxmium l

# Plot Energy Levels of Cesium
levels = LevelPlot(atom)
levels.makeLevels(nmin, nmax, lmin, lmax)
levels.drawLevels("GHz")
levels.showPlot()
# plot is interactive when called outside the IPython notebook (e.g. from Python program)

# %%
a = atom.getEnergy(126, 0, 0.5) * 241799.0504
print(a)
# Out:
# -221.21032394612826

# %%
b = atom.getEnergy(124, 2, 2.5) * 241799.0504
print(b)
# Out:
# -222.7307324221593

# %%
a-b, "GHz"
# Out:
# (1.5204084760310366, 'GHz')

# %%
atom.getStateLifetime(43, 2, 2.5)
# Out:
# 7.909963866348781e-05

# %%
atom.getStateLifetime(53, 0, 0.5)
# Out:
# 0.00015525245010033172

# %%
mg = 8.5/10000 # tesla

# %%
atom.getZeemanEnergyShift(0, 0.5, 0.5, mg)
# Out:
# 7.89204999866904e-27

# %%
r*1.50919031167677E+33/1000000
# Out:
# 11.910605397259982
